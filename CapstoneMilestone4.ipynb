# %% [markdown]
# ### Capstone Milestone 4 Assignment

# %% [markdown]
# #### 1. Executive Summary
#
# What is your goal?  My goal is to evaluate text from numerous writers to determine if personality can be predicted with Machine learning.  I have chosen to use the cross val score to determine the accuracy of the model with a success threshold of 0.75.
#
# Where did you get your data?  This data was collected through the PersonalityCafe forum, as it provides a large selection of people and their MBTI personality type, as well as what they have written in posts on the forum.  The data was already in a csv file and posted on Kaggle.
#
# What are your metrics?   Metrics I have chosen to use as mentioned above are the cross val score to determine the accuracy of the model.
#
# What were your findings?  I found the following results:
#
# Screen Shot 2018-10-20 at 11.44.05 PM![image.png](attachment:image.png)

# %% [markdown]
# ##### .
# What risks/limitations/assumptions affect these findings?   There is an unfortunate imbalance of personality types in the dataset.  When looking at the 16 different personality types, there is a range of 1700 to below 100 individuals with the different personality types.  See the below chart:
#
# Screen Shot 2018-10-21 at 12.01.52 AM![image.png](attachment:image.png)

# %% [markdown]
# #### .
# Because of this imbalance, I have chosen to evaluate the four different categories separately for which there is a much more even distribution of data. I added four additional columns to the data set in order to evaluate each of the four functions individually. Here is the breakdown of the distribution of the four functions:
#
# Screen Shot 2018-10-21 at 10.22.01 AM![image.png](attachment:image.png)

# %% [markdown]
# #### .
#
# See the below histogram showing the distribution of each of the four functions:
#
# Screen Shot 2018-10-21 at 12.00.57 AM![image.png](attachment:image.png)

# %% [markdown]
# #### .
#
# Due to the fact that the data was obtained from a Personality forum site, text specifically related to personality had to be added to the stop words (removed from evaluated text) to prevent bias from affecting the accuracy results.   In researching the effectiveness of functions added to detect sarcasm, metaphor and irony, it is apparent that machine learning is not effective at this.  This is likely because irony, humor, satire, sarcasm, and metaphor all have specific cultural, and historical contexts and sometimes are very specific to certain groups/subgroups in subtle and nuanced ways.   The machine would have to be knowledgeable of the context of the language and intent of the author to pick up on these aspects of language more effectively. See link below to paper written by Stanford students regarding the above mentioned machine learning limitations:
# http://cs229.stanford.edu/proj2015/044_report.pdf

# %% [markdown]
# #### 2. Summarize your statistical analysis, including:
#
# implementation: Logistic regression model was applied to all four personality functions with an success threshold of the model accuracy being greater than 75%.  A random forest model; extra trees classifier and multinomial gridsearch were used as well.  Logistic regression was ultimately chosen as the model for final evaluation as the important text features for each personality function could be evaluated.  The Count Vectorizer function was used to convert text before it was run through the model.
#
# evaluation:As mentioned above, three of the four functions met the 75% threshold requirement.   Judging/Perception was the only function that did not meet the requirement--the LR score for JP was 0.644.
#
# inference:
#
# Despite the fact that there is significant overfitting with the LR model, the results were very encouraging.  Due to the subjective nature of personality assesment, I was unsure if personality types could be predicted.  In the future I would like to see if a model could be developed to accuratly predict from the 16 specific personality types using a multiclassification model.
#
# Overall, adding objectivity to the well established Meyers Briggs Test adds credibility to the test and to the importance/potential of people understanding their personal makeup in order to gain clarity, purpose, and direction for their life in general--which I believe is as relevant and useful as ever.

# %% [markdown]
# #### 3. See the individual notebooks for details.
# #4. Clearly document all of your decision points in the relevant sections
# How did you acquire your data?  As mentioned above, the data was obtained from Kaggle.  An individual collected the data from Personality Cafe Forum.
# How did you transform or engineer your data? Why?  The posts were transformed into numeric data for evalution with classification models.  Four additional columns were added for the four functions of the MB personality.  Each of these four columns were targets evaluated separately.  Also, the vader sentiment function was applied and four columns were added.
# How did you select your model?  The Linear Regression model is the mose versatile as it allows for the evaluation of individual features.  Also, three of the four functions passed the threshold of 75% accuarcy.  The JP function is the only one that did not.
# How did you optimize hyperparameters?  Due to the number of features (115,936 Columns) hyperparameters were kept fairly simple to allow for my computer to run the models.

# %% [markdown]
# #### 5. See attached Readme file.

# %% [markdown]
# ##### see coding docs for the four functions in the EDA folder.
